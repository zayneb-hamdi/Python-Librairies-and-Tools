# %%
print("hello world")
# Out:
# hello world

# %%
import  numpy as np
import  pandas as pd
import matplotlib.pyplot as plt

# %%
x=np.linspace(-10,10,100)
y=np.sin(x)
plt.plot(x,y,marker=".")

# %%
data={'name':['zayneb','mariem','youssef'],'age':[23,21,19],'location':['Japan','Holland','Germany']}
frame=pd.DataFrame(data)
display(frame)
# Out:
#       name  age location
# 0   zayneb   23    Japan
# 1   mariem   21  Holland
# 2  youssef   19  Germany

# %%
plt.figure(1)
plt.pie(x = [8000,20000,16200], labels = ['math','sciences','economie'],
           colors = ["#f33030","#218E12","#1448E3"],
           autopct = lambda x: str(round(x, 2)) + '%')
plt.legend()
